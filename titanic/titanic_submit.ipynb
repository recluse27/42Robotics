# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn import metrics, model_selection
import glob
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir("."))
# Out:
# /home/lazukav/anaconda3/lib/python3.5/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ['titanic_submit.ipynb', '.ipynb_checkpoints', 'model2.csv', 'test.csv', 'train.csv', 'titanic_submit-old_copy.ipynb', 'model4.csv', 'model3.csv', 'model1.csv', 'model5.csv']

# %%
def data_split(data):
#     data = data.sample(frac=1)
    Y = data['Survived']
    X = data.drop(['Survived'], axis=1)
    return X, Y

# def load_data(train_path='train.csv', test_path='test.csv', test_labels='gender_submission.csv'):
def load_data(train_path='train.csv', test_path='test.csv'):
    train = pd.DataFrame.from_csv(train_path, index_col=0)
    test_X = pd.DataFrame.from_csv(test_path, index_col=0)
#     test_Y.drop([0], inplace=True)
#     test_Y = pd.Series.from_csv(test_labels)
    train_X, train_Y = data_split(train)
              
#     print(train.head())
#     print(test_Y.head())
    return train_X, train_Y, test_X

# %%
train_X, train_Y, test_X = load_data()
print(train_X.shape, train_Y.shape)
print(test_X.shape)
# Out:
# (891, 10) (891,)
# (418, 10)
# /home/lazukav/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:9: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   if __name__ == '__main__':
# /home/lazukav/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:10: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# # EDA

# %%
def data_stat(data):
    print("Describe: ", data.describe(), sep='\n')
    print("Correlation: ", data.corr(), sep='\n')
    print("#NaN: ", data.isna().sum(), sep='\n')

# %%
data_stat(train_X)
# Out:
# Describe:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200
# Correlation:
#           Pclass       Age     SibSp     Parch      Fare
# Pclass  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age    -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp   0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch   0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare   -0.549500  0.096067  0.159651  0.216225  1.000000
# #NaN:
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
train = pd.DataFrame.from_csv('train.csv', index_col=0)
train.Age[train.Survived==1].hist()
# train.Age.hist()
# train[train.Age.isna()]
# Out:
# /home/lazukav/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
# train['Relatives'] = train['SibSp'] + train['Parch']
# train.corr()
# train = pd.get_dummies(train, columns=['Pclass'])
# train.head()
# test.isna().sum()
# train.drop(['SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1, inplace=True)

# %% [markdown]
# # MODEL 1 params=[gender]

# %%
# train_X, train_Y, test_X = load_data()

def proc_data(data):
    sex_mapping = {
        'male': 1,
        'female': 0
    }
    data['Sex'] = data['Sex'].map(sex_mapping)
    male_mean_age = data[data["Sex"]==1]["Age"].mean()
    female_mean_age = data[data["Sex"]==0]["Age"].mean()
    
    data.loc[ (data["Sex"]==1) & (data["Age"].isnull()), "Age"] = male_mean_age
    data.loc[ (data["Sex"]==0) & (data["Age"].isnull()), "Age"] = female_mean_age
    data.drop(['Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1, inplace=True)
    data = pd.get_dummies(data, columns=['Pclass'])
    data['Relatives'] = data['SibSp'] + data['Parch']

    return data

train_X = proc_data(train_X)
test_X = proc_data(test_X)

# %%
train_X.columns
# Out:
# Index(['Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Pclass_1', 'Pclass_2',
#        'Pclass_3', 'Relatives'],
#       dtype='object')

# %%
sex = tf.feature_column.numeric_column('Sex')
age = tf.feature_column.numeric_column('Age')
age_bucket = tf.feature_column.bucketized_column(age, [8, 16, 21, 32, 40, 55])
sibsp = tf.feature_column.numeric_column('SibSp')
parch = tf.feature_column.numeric_column('Parch')
pclass1 = tf.feature_column.numeric_column('Pclass_1')
pclass2 = tf.feature_column.numeric_column('Pclass_2')
pclass3 = tf.feature_column.numeric_column('Pclass_3')
relatives = tf.feature_column.numeric_column('Relatives')

# sex_feature = tf.feature_column.categorical_column_with_vocabulary_list(
#     'Sex',['female','male'])


cols = [sex]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_X, train_Y, test_size=0.2, shuffle=None)

# %% [markdown]
# # Full estimators

# %%
def train_classification_model(
    learning_rate,
    steps,
    batch_size,
    X_train,
    y_train,
    X_test,
    y_test,
    cols,
    m_dir,
    periods):

    steps_per_period = steps / periods  

    training_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        shuffle=True,
    )

    ptraining_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        num_epochs=1,
        shuffle=False,
    )

    validation_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_test,
        y=y_test,
        num_epochs=1,
        shuffle=False 
    )

    # Create a LinearClassifier object.
    my_optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
    classifier = tf.estimator.DNNClassifier(
        feature_columns=cols,
        n_classes=2,
        optimizer=my_optimizer,
        hidden_units=[64, 128, 64],
        model_dir=m_dir
    )

    # Train the model, but do so inside a loop so that we can periodically assess
    # loss metrics.
    print("Training model...")
    print("LogLoss error (on validation data):")
    training_errors = []
    validation_errors = []
    for period in range (0, periods):
        # Train the model, starting from the prior state.
        classifier.train(
            input_fn=training_input_fn,
            steps=steps_per_period
        )
        classifier.evaluate(input_fn=validation_input_fn)
        # Take a break and compute probabilities.
        training_predictions = list(classifier.predict(input_fn=ptraining_input_fn))
        training_probabilities = np.array([item['probabilities'] for item in training_predictions])
        training_pred_class_id = np.array([item['class_ids'][0] for item in training_predictions])
        training_pred_one_hot = tf.keras.utils.to_categorical(training_pred_class_id, 2)

        validation_predictions = list(classifier.predict(input_fn=validation_input_fn))
        validation_probabilities = np.array([item['probabilities'] for item in validation_predictions])    
        validation_pred_class_id = np.array([item['class_ids'][0] for item in validation_predictions])
        validation_pred_one_hot = tf.keras.utils.to_categorical(validation_pred_class_id, 2)    
        print("Hey")
        # Compute training and validation errors.
        training_log_loss = metrics.log_loss(y_train, training_pred_one_hot)
        validation_log_loss = metrics.log_loss(y_test, validation_pred_one_hot)
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, validation_log_loss))
        # Add the loss metrics from this period to our list.
        training_errors.append(training_log_loss)
        validation_errors.append(validation_log_loss)
    print("Model training finished.")
    # Remove event files to save disk space.
    _ = map(os.remove, glob.glob(os.path.join(classifier.model_dir, 'events.out.tfevents*')))

    # Calculate final predictions (not probabilities, as above).
    final_predictions = classifier.predict(input_fn=validation_input_fn)
    final_predictions = np.array([item['class_ids'][0] for item in final_predictions])


    accuracy = metrics.accuracy_score(y_test, final_predictions)
    print("Final accuracy (on validation data): %0.2f" % accuracy)

    # Output a graph of loss metrics over periods.
    plt.ylabel("LogLoss")
    plt.xlabel("Periods")
    plt.title("LogLoss vs. Periods")
    plt.plot(training_errors, label="training")
    plt.plot(validation_errors, label="validation")
    plt.legend()
    plt.show()

    # Output a plot of the confusion matrix.
    cm = metrics.confusion_matrix(y_test, final_predictions)
    # Normalize the confusion matrix by row (i.e by the number of samples
    # in each class).
    cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm_normalized, cmap="bone_r")
    ax.set_aspect(1)
    plt.title("Confusion matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.show()

    return classifier

# %% [markdown]
# # Model1 (0.76555)

# %%
cols = [sex]

# %%
model1 = train_classification_model(
    learning_rate=0.01,
    steps=100,
    batch_size=20,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    cols=cols,
    m_dir='/tmp/model1',
    periods=10)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_experimental_distribute': None, '_tf_random_seed': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_model_dir': '/tmp/model1', '_task_type': 'worker', '_train_distribute': None, '_num_ps_replicas': 0, '_device_fn': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_service': None, '_master': '', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8441b0e4e0>, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 600, '_eval_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None}
# Training model...
# LogLoss error (on validation data):
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-60
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py:1070: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 61.520252, step = 61
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model1/model.ckpt.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Loss for final step: 40.60083.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:18:38Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:18:38
# INFO:tensorflow:Saving dict for global step 66: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5274282, global_step = 66, label/mean = 0.36312848, loss = 47.204826, precision = 0.71929824, prediction/mean = 0.3627911, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: /tmp/model1/model.ckpt-66
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 00 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 72.66208, step = 67
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 35.094307.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:18:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:18:43
# INFO:tensorflow:Saving dict for global step 72: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.52920705, global_step = 72, label/mean = 0.36312848, loss = 47.364033, precision = 0.71929824, prediction/mean = 0.35090017, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72: /tmp/model1/model.ckpt-72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 01 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 63.65213, step = 73
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 34.300358.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:18:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:18:48
# INFO:tensorflow:Saving dict for global step 78: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5283887, global_step = 78, label/mean = 0.36312848, loss = 47.290787, precision = 0.71929824, prediction/mean = 0.35522836, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78: /tmp/model1/model.ckpt-78
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 02 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 65.38727, step = 79
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 38.077003.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:18:52Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:18:53
# INFO:tensorflow:Saving dict for global step 84: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5281847, global_step = 84, label/mean = 0.36312848, loss = 47.27253, precision = 0.71929824, prediction/mean = 0.35795674, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84: /tmp/model1/model.ckpt-84
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 03 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 65.99572, step = 85
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 36.292206.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:18:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:18:57
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5281267, global_step = 90, label/mean = 0.36312848, loss = 47.26734, precision = 0.71929824, prediction/mean = 0.35951203, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: /tmp/model1/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 04 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 67.98525, step = 91
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 42.325478.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:02
# INFO:tensorflow:Saving dict for global step 96: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5278656, global_step = 96, label/mean = 0.36312848, loss = 47.243973, precision = 0.71929824, prediction/mean = 0.36412188, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: /tmp/model1/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 05 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 58.766922, step = 97
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 34.90357.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:06
# INFO:tensorflow:Saving dict for global step 102: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.52796024, global_step = 102, label/mean = 0.36312848, loss = 47.25244, precision = 0.71929824, prediction/mean = 0.35625327, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 102: /tmp/model1/model.ckpt-102
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 06 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 67.16872, step = 103
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 45.514168.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:11
# INFO:tensorflow:Saving dict for global step 108: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5291266, global_step = 108, label/mean = 0.36312848, loss = 47.356827, precision = 0.71929824, prediction/mean = 0.39058772, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 108: /tmp/model1/model.ckpt-108
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 07 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 69.77612, step = 109
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 31.094463.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:15
# INFO:tensorflow:Saving dict for global step 114: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5282812, global_step = 114, label/mean = 0.36312848, loss = 47.281166, precision = 0.71929824, prediction/mean = 0.3567068, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 114: /tmp/model1/model.ckpt-114
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 08 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model1/model.ckpt.
# INFO:tensorflow:loss = 56.451633, step = 115
# INFO:tensorflow:Saving checkpoints for 120 into /tmp/model1/model.ckpt.
# INFO:tensorflow:Loss for final step: 35.502113.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:20
# INFO:tensorflow:Saving dict for global step 120: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.74520916, auc_precision_recall = 0.7420729, average_loss = 0.5282771, global_step = 120, label/mean = 0.36312848, loss = 47.2808, precision = 0.71929824, prediction/mean = 0.36148173, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 120: /tmp/model1/model.ckpt-120
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 09 : 7.72
# Model training finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Final accuracy (on validation data): 0.78

# %%
scores1 = model1.predict(input_fn=tf.estimator.inputs.pandas_input_fn(x=test_X,
                                                                      num_epochs=1,
                                                                      shuffle=False))

res = []
for i, p in enumerate(scores1):
#     print(i + 892, p['class_ids'][0])
    res.append([i + 892, p['class_ids'][0]])   

#to df then to series and save to file
result = pd.DataFrame(res, columns=['PassengerId', 'Survived'])
result.to_csv('model1.csv', index=None)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model1/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Model 2 (0.76555)

# %%
cols = [sex, pclass1, pclass2, pclass3]

# %%
model2 = train_classification_model(
    learning_rate=0.01,
    steps=100,
    batch_size=20,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    cols=cols,
    m_dir='/tmp/model2',
    periods=10)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_experimental_distribute': None, '_tf_random_seed': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_model_dir': '/tmp/model2', '_task_type': 'worker', '_train_distribute': None, '_num_ps_replicas': 0, '_device_fn': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_service': None, '_master': '', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f839ffa9b70>, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 600, '_eval_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None}
# Training model...
# LogLoss error (on validation data):
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 51.285957, step = 61
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 27.60601.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:26
# INFO:tensorflow:Saving dict for global step 66: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.50190926, global_step = 66, label/mean = 0.36312848, loss = 44.92088, precision = 0.71929824, prediction/mean = 0.3723231, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: /tmp/model2/model.ckpt-66
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 00 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 48.848125, step = 67
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 43.86296.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:31
# INFO:tensorflow:Saving dict for global step 72: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.50100523, global_step = 72, label/mean = 0.36312848, loss = 44.83997, precision = 0.71929824, prediction/mean = 0.36033928, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72: /tmp/model2/model.ckpt-72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 01 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 52.14334, step = 73
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.42961.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:35
# INFO:tensorflow:Saving dict for global step 78: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.50212795, global_step = 78, label/mean = 0.36312848, loss = 44.940453, precision = 0.90909094, prediction/mean = 0.34844506, recall = 0.46153846
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78: /tmp/model2/model.ckpt-78
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 02 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 53.111244, step = 79
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 29.34811.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:40
# INFO:tensorflow:Saving dict for global step 84: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.50136465, global_step = 84, label/mean = 0.36312848, loss = 44.872135, precision = 0.71929824, prediction/mean = 0.3600255, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84: /tmp/model2/model.ckpt-84
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 03 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 48.056812, step = 85
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 44.004894.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:44Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:45
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.51747096, global_step = 90, label/mean = 0.36312848, loss = 46.31365, precision = 0.71929824, prediction/mean = 0.41312546, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: /tmp/model2/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 04 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 56.128883, step = 91
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 35.96987.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:50
# INFO:tensorflow:Saving dict for global step 96: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.5060742, global_step = 96, label/mean = 0.36312848, loss = 45.29364, precision = 0.90909094, prediction/mean = 0.36284846, recall = 0.46153846
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: /tmp/model2/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 05 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 56.900574, step = 97
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 32.668674.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:55
# INFO:tensorflow:Saving dict for global step 102: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.51461774, global_step = 102, label/mean = 0.36312848, loss = 46.05829, precision = 0.71929824, prediction/mean = 0.38839695, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 102: /tmp/model2/model.ckpt-102
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 06 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 51.278732, step = 103
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 33.4178.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:19:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:19:59
# INFO:tensorflow:Saving dict for global step 108: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.50806975, global_step = 108, label/mean = 0.36312848, loss = 45.47224, precision = 0.71929824, prediction/mean = 0.37538615, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 108: /tmp/model2/model.ckpt-108
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 07 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 50.971436, step = 109
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.195417.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:04
# INFO:tensorflow:Saving dict for global step 114: accuracy = 0.7765363, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.5077652, global_step = 114, label/mean = 0.36312848, loss = 45.44498, precision = 0.71929824, prediction/mean = 0.38244113, recall = 0.63076925
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 114: /tmp/model2/model.ckpt-114
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 08 : 7.72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model2/model.ckpt.
# INFO:tensorflow:loss = 46.603424, step = 115
# INFO:tensorflow:Saving checkpoints for 120 into /tmp/model2/model.ckpt.
# INFO:tensorflow:Loss for final step: 36.628952.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:09
# INFO:tensorflow:Saving dict for global step 120: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.78225374, auc_precision_recall = 0.76326644, average_loss = 0.5021033, global_step = 120, label/mean = 0.36312848, loss = 44.938248, precision = 0.90909094, prediction/mean = 0.36553183, recall = 0.46153846
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 120: /tmp/model2/model.ckpt-120
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 09 : 7.33
# Model training finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Final accuracy (on validation data): 0.79

# %%
scores2 = model2.predict(input_fn=tf.estimator.inputs.pandas_input_fn(x=test_X,
                                                                      num_epochs=1,
                                                                      shuffle=False))

res = []
for i, p in enumerate(scores2):
#     print(i + 892, p['class_ids'][0])
    res.append([i + 892, p['class_ids'][0]])   

#to df then to series and save to file
result = pd.DataFrame(res, columns=['PassengerId', 'Survived'])
result.to_csv('model2.csv', index=None)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model2/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Model 3 (0.73205)

# %%
cols = [sex, pclass1, pclass2, pclass3, age_bucket]

# %%
model3 = train_classification_model(
    learning_rate=0.01,
    steps=100,
    batch_size=20,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    cols=cols,
    m_dir='/tmp/model3',
    periods=10)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_experimental_distribute': None, '_tf_random_seed': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_model_dir': '/tmp/model3', '_task_type': 'worker', '_train_distribute': None, '_num_ps_replicas': 0, '_device_fn': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_service': None, '_master': '', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f84401e23c8>, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 600, '_eval_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None}
# Training model...
# LogLoss error (on validation data):
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/feature_column/feature_column_v2.py:2851: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 58.25902, step = 61
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.344196.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:14Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:15
# INFO:tensorflow:Saving dict for global step 66: accuracy = 0.7932961, accuracy_baseline = 0.6368715, auc = 0.79635626, auc_precision_recall = 0.7808552, average_loss = 0.48575178, global_step = 66, label/mean = 0.36312848, loss = 43.474785, precision = 0.71875, prediction/mean = 0.38957077, recall = 0.7076923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: /tmp/model3/model.ckpt-66
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 00 : 7.14
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 42.6521, step = 67
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 24.163605.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:20
# INFO:tensorflow:Saving dict for global step 72: accuracy = 0.7932961, accuracy_baseline = 0.6368715, auc = 0.7922402, auc_precision_recall = 0.775895, average_loss = 0.49309203, global_step = 72, label/mean = 0.36312848, loss = 44.131737, precision = 0.71875, prediction/mean = 0.4002472, recall = 0.7076923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72: /tmp/model3/model.ckpt-72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 01 : 7.14
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 59.38326, step = 73
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 34.284.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:26
# INFO:tensorflow:Saving dict for global step 78: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.79352224, auc_precision_recall = 0.780029, average_loss = 0.4920896, global_step = 78, label/mean = 0.36312848, loss = 44.04202, precision = 0.71428573, prediction/mean = 0.38494408, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78: /tmp/model3/model.ckpt-78
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 02 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 61.517513, step = 79
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 21.951435.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:30
# INFO:tensorflow:Saving dict for global step 84: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.7962213, auc_precision_recall = 0.7816671, average_loss = 0.4915361, global_step = 84, label/mean = 0.36312848, loss = 43.99248, precision = 0.71428573, prediction/mean = 0.35621437, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84: /tmp/model3/model.ckpt-84
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 03 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 49.7334, step = 85
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 22.72823.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:35
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.79385966, auc_precision_recall = 0.7805533, average_loss = 0.50228333, global_step = 90, label/mean = 0.36312848, loss = 44.95436, precision = 0.71428573, prediction/mean = 0.39398116, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: /tmp/model3/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 04 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 47.172108, step = 91
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 32.891388.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:41
# INFO:tensorflow:Saving dict for global step 96: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.7912956, auc_precision_recall = 0.77631223, average_loss = 0.4987702, global_step = 96, label/mean = 0.36312848, loss = 44.639935, precision = 0.71428573, prediction/mean = 0.4019043, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: /tmp/model3/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 05 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 49.20132, step = 97
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 32.388634.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:44Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:45
# INFO:tensorflow:Saving dict for global step 102: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.7917004, auc_precision_recall = 0.7770436, average_loss = 0.49309966, global_step = 102, label/mean = 0.36312848, loss = 44.13242, precision = 0.71428573, prediction/mean = 0.38109913, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 102: /tmp/model3/model.ckpt-102
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 06 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 47.20244, step = 103
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.273952.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:50
# INFO:tensorflow:Saving dict for global step 108: accuracy = 0.7932961, accuracy_baseline = 0.6368715, auc = 0.7929149, auc_precision_recall = 0.78289485, average_loss = 0.4864196, global_step = 108, label/mean = 0.36312848, loss = 43.534554, precision = 0.73333335, prediction/mean = 0.3664762, recall = 0.6769231
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 108: /tmp/model3/model.ckpt-108
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 07 : 7.14
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 42.879562, step = 109
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 38.47401.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:20:55
# INFO:tensorflow:Saving dict for global step 114: accuracy = 0.7877095, accuracy_baseline = 0.6368715, auc = 0.7880567, auc_precision_recall = 0.7745211, average_loss = 0.4981843, global_step = 114, label/mean = 0.36312848, loss = 44.587494, precision = 0.71428573, prediction/mean = 0.41185525, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 114: /tmp/model3/model.ckpt-114
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 08 : 7.33
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model3/model.ckpt.
# INFO:tensorflow:loss = 51.343307, step = 115
# INFO:tensorflow:Saving checkpoints for 120 into /tmp/model3/model.ckpt.
# INFO:tensorflow:Loss for final step: 20.539751.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:20:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:00
# INFO:tensorflow:Saving dict for global step 120: accuracy = 0.7932961, accuracy_baseline = 0.6368715, auc = 0.7935898, auc_precision_recall = 0.7786387, average_loss = 0.48943537, global_step = 120, label/mean = 0.36312848, loss = 43.804466, precision = 0.73333335, prediction/mean = 0.36233914, recall = 0.6769231
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 120: /tmp/model3/model.ckpt-120
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 09 : 7.14
# Model training finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Final accuracy (on validation data): 0.79

# %%
scores3 = model3.predict(input_fn=tf.estimator.inputs.pandas_input_fn(x=test_X,
                                                                      num_epochs=1,
                                                                      shuffle=False))

res = []
for i, p in enumerate(scores3):
#     print(i + 892, p['class_ids'][0])
    res.append([i + 892, p['class_ids'][0]])   

#to df then to series and save to file
result = pd.DataFrame(res, columns=['PassengerId', 'Survived'])
result.to_csv('model3.csv', index=None)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model3/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # MODEL 4 (0.74162)

# %%
cols = [sex, pclass1, pclass2, pclass3, age_bucket, relatives]

# %%
model4 = train_classification_model(
    learning_rate=0.01,
    steps=100,
    batch_size=20,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    cols=cols,
    m_dir='/tmp/model4',
    periods=10)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_experimental_distribute': None, '_tf_random_seed': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_model_dir': '/tmp/model4', '_task_type': 'worker', '_train_distribute': None, '_num_ps_replicas': 0, '_device_fn': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_service': None, '_master': '', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8394b779b0>, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 600, '_eval_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None}
# Training model...
# LogLoss error (on validation data):
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 47.688843, step = 61
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 34.58065.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:05Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:06
# INFO:tensorflow:Saving dict for global step 66: accuracy = 0.81005585, accuracy_baseline = 0.6368715, auc = 0.81599194, auc_precision_recall = 0.80251306, average_loss = 0.4675033, global_step = 66, label/mean = 0.36312848, loss = 41.841545, precision = 0.75409836, prediction/mean = 0.3830649, recall = 0.7076923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 66: /tmp/model4/model.ckpt-66
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 00 : 6.56
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-66
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 55.895184, step = 67
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.513334.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:11Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:12
# INFO:tensorflow:Saving dict for global step 72: accuracy = 0.82122904, accuracy_baseline = 0.6368715, auc = 0.81511474, auc_precision_recall = 0.80299574, average_loss = 0.4618266, global_step = 72, label/mean = 0.36312848, loss = 41.33348, precision = 0.779661, prediction/mean = 0.35148832, recall = 0.7076923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 72: /tmp/model4/model.ckpt-72
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 01 : 6.17
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-72
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 41.98426, step = 73
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 30.47994.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:16
# INFO:tensorflow:Saving dict for global step 78: accuracy = 0.8156425, accuracy_baseline = 0.6368715, auc = 0.8153846, auc_precision_recall = 0.8033582, average_loss = 0.46196657, global_step = 78, label/mean = 0.36312848, loss = 41.34601, precision = 0.7758621, prediction/mean = 0.35348335, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78: /tmp/model4/model.ckpt-78
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 02 : 6.37
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-78
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 78 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 42.79492, step = 79
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 21.384254.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:20
# INFO:tensorflow:Saving dict for global step 84: accuracy = 0.8156425, accuracy_baseline = 0.6368715, auc = 0.8142375, auc_precision_recall = 0.80374396, average_loss = 0.4683623, global_step = 84, label/mean = 0.36312848, loss = 41.918427, precision = 0.7758621, prediction/mean = 0.35016426, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 84: /tmp/model4/model.ckpt-84
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 03 : 6.37
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-84
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 84 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 48.610695, step = 85
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.696709.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:26
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.76536316, accuracy_baseline = 0.6368715, auc = 0.8227396, auc_precision_recall = 0.8042812, average_loss = 0.48433784, global_step = 90, label/mean = 0.36312848, loss = 43.348236, precision = 0.6533333, prediction/mean = 0.42381236, recall = 0.75384617
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: /tmp/model4/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 04 : 8.10
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 54.965908, step = 91
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 24.962692.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:30
# INFO:tensorflow:Saving dict for global step 96: accuracy = 0.8156425, accuracy_baseline = 0.6368715, auc = 0.8165992, auc_precision_recall = 0.8001709, average_loss = 0.47184616, global_step = 96, label/mean = 0.36312848, loss = 42.230232, precision = 0.78571427, prediction/mean = 0.33301413, recall = 0.6769231
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: /tmp/model4/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 05 : 6.37
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 96 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 40.63614, step = 97
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 27.403696.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:36
# INFO:tensorflow:Saving dict for global step 102: accuracy = 0.82122904, accuracy_baseline = 0.6368715, auc = 0.8210527, auc_precision_recall = 0.80174506, average_loss = 0.47390363, global_step = 102, label/mean = 0.36312848, loss = 42.414375, precision = 0.779661, prediction/mean = 0.3843053, recall = 0.7076923
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 102: /tmp/model4/model.ckpt-102
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 06 : 6.17
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 102 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 47.30578, step = 103
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.298752.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:41
# INFO:tensorflow:Saving dict for global step 108: accuracy = 0.7709497, accuracy_baseline = 0.6368715, auc = 0.8199055, auc_precision_recall = 0.79912424, average_loss = 0.48628256, global_step = 108, label/mean = 0.36312848, loss = 43.52229, precision = 0.6621622, prediction/mean = 0.4132765, recall = 0.75384617
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 108: /tmp/model4/model.ckpt-108
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 07 : 7.91
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-108
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 108 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 64.19054, step = 109
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 20.279434.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:46
# INFO:tensorflow:Saving dict for global step 114: accuracy = 0.8156425, accuracy_baseline = 0.6368715, auc = 0.82091767, auc_precision_recall = 0.8016667, average_loss = 0.4742845, global_step = 114, label/mean = 0.36312848, loss = 42.448463, precision = 0.7758621, prediction/mean = 0.3605657, recall = 0.6923077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 114: /tmp/model4/model.ckpt-114
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 08 : 6.37
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-114
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 114 into /tmp/model4/model.ckpt.
# INFO:tensorflow:loss = 46.352646, step = 115
# INFO:tensorflow:Saving checkpoints for 120 into /tmp/model4/model.ckpt.
# INFO:tensorflow:Loss for final step: 24.537888.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:51
# INFO:tensorflow:Saving dict for global step 120: accuracy = 0.7709497, accuracy_baseline = 0.6368715, auc = 0.81923074, auc_precision_recall = 0.7946062, average_loss = 0.4862333, global_step = 120, label/mean = 0.36312848, loss = 43.51788, precision = 0.67142856, prediction/mean = 0.41125762, recall = 0.72307694
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 120: /tmp/model4/model.ckpt-120
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 09 : 7.91
# Model training finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Final accuracy (on validation data): 0.77

# %%
scores4 = model4.predict(input_fn=tf.estimator.inputs.pandas_input_fn(x=test_X,
                                                                      num_epochs=1,
                                                                      shuffle=False))

res = []
for i, p in enumerate(scores4):
#     print(i + 892, p['class_ids'][0])
    res.append([i + 892, p['class_ids'][0]])   

#to df then to series and save to file
result = pd.DataFrame(res, columns=['PassengerId', 'Survived'])
result.to_csv('model4.csv', index=None)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model4/model.ckpt-120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# # Boosted trees (0.62679)

# %%
def train_classification_model(
    learning_rate,
    steps,
    batch_size,
    X_train,
    y_train,
    X_test,
    y_test,
    cols,
    m_dir,
    periods):

    steps_per_period = steps / periods  

    training_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        shuffle=True,
    )

    ptraining_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        num_epochs=1,
        shuffle=False,
    )

    validation_input_fn = tf.estimator.inputs.pandas_input_fn(
        x=X_test,
        y=y_test,
        num_epochs=1,
        shuffle=False 
    )

    classifier = tf.estimator.BoostedTreesClassifier(
        feature_columns=cols,
        n_batches_per_layer=batch_size,
        n_classes=2,
        n_trees=20,
        model_dir=m_dir
    )

    # Train the model, but do so inside a loop so that we can periodically assess
    # loss metrics.
    print("Training model...")
    print("LogLoss error (on validation data):")
    training_errors = []
    validation_errors = []
    for period in range (0, periods):
        # Train the model, starting from the prior state.
        classifier.train(
            input_fn=training_input_fn,
            steps=steps_per_period
        )
        classifier.evaluate(input_fn=validation_input_fn)
        # Take a break and compute probabilities.
        training_predictions = list(classifier.predict(input_fn=ptraining_input_fn))
        training_probabilities = np.array([item['probabilities'] for item in training_predictions])
        training_pred_class_id = np.array([item['class_ids'][0] for item in training_predictions])
        training_pred_one_hot = tf.keras.utils.to_categorical(training_pred_class_id, 2)

        validation_predictions = list(classifier.predict(input_fn=validation_input_fn))
        validation_probabilities = np.array([item['probabilities'] for item in validation_predictions])    
        validation_pred_class_id = np.array([item['class_ids'][0] for item in validation_predictions])
        validation_pred_one_hot = tf.keras.utils.to_categorical(validation_pred_class_id, 2)    
        print("Hey")
        # Compute training and validation errors.
        training_log_loss = metrics.log_loss(y_train, training_pred_one_hot)
        validation_log_loss = metrics.log_loss(y_test, validation_pred_one_hot)
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, validation_log_loss))
        # Add the loss metrics from this period to our list.
        training_errors.append(training_log_loss)
        validation_errors.append(validation_log_loss)
    print("Model training finished.")
    # Remove event files to save disk space.
    _ = map(os.remove, glob.glob(os.path.join(classifier.model_dir, 'events.out.tfevents*')))

    # Calculate final predictions (not probabilities, as above).
    final_predictions = classifier.predict(input_fn=validation_input_fn)
    final_predictions = np.array([item['class_ids'][0] for item in final_predictions])


    accuracy = metrics.accuracy_score(y_test, final_predictions)
    print("Final accuracy (on validation data): %0.2f" % accuracy)

    # Output a graph of loss metrics over periods.
    plt.ylabel("LogLoss")
    plt.xlabel("Periods")
    plt.title("LogLoss vs. Periods")
    plt.plot(training_errors, label="training")
    plt.plot(validation_errors, label="validation")
    plt.legend()
    plt.show()

    # Output a plot of the confusion matrix.
    cm = metrics.confusion_matrix(y_test, final_predictions)
    # Normalize the confusion matrix by row (i.e by the number of samples
    # in each class).
    cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm_normalized, cmap="bone_r")
    ax.set_aspect(1)
    plt.title("Confusion matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.show()

    return classifier

# %%
model5 = train_classification_model(
    learning_rate=0.01,
    steps=100,
    batch_size=20,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    cols=cols,
    m_dir='/tmp/model5',
    periods=10)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_experimental_distribute': None, '_tf_random_seed': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_model_dir': '/tmp/model5', '_task_type': 'worker', '_train_distribute': None, '_num_ps_replicas': 0, '_device_fn': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_protocol': None, '_service': None, '_master': '', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f83132b6fd0>, '_global_id_in_cluster': 0, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_save_checkpoints_secs': 600, '_eval_distribute': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None}
# Training model...
# LogLoss error (on validation data):
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/feature_column/feature_column.py:2121: BucketizedColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /home/lazukav/anaconda3/lib/python3.5/site-packages/tensorflow/python/feature_column/feature_column.py:2121: NumericColumn._transform_feature (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:21:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:21:56
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 00 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:01
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 01 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:04
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 02 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:07
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 03 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:09Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:10
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 04 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:13
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 05 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:18
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 06 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:21
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 07 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:23Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:24
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 08 : 12.54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model5/model.ckpt.
# WARNING:tensorflow:Issue encountered when serializing resources.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# '_Resource' object has no attribute 'name'
# INFO:tensorflow:loss = 0.6931473, step = 0
# INFO:tensorflow:Loss for final step: 0.6931472.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15T18:22:26Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-18:22:27
# INFO:tensorflow:Saving dict for global step 0: accuracy = 0.6368715, accuracy_baseline = 0.6368715, auc = 0.5, auc_precision_recall = 0.6815642, average_loss = 0.6931473, global_step = 0, label/mean = 0.36312848, loss = 0.69314724, precision = 0.0, prediction/mean = 0.5, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 0: /tmp/model5/model.ckpt-0
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Hey
#   period 09 : 12.54
# Model training finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Final accuracy (on validation data): 0.64

# %%
scores5 = model5.predict(input_fn=tf.estimator.inputs.pandas_input_fn(x=test_X,
                                                                      num_epochs=1,
                                                                      shuffle=False))

res = []
for i, p in enumerate(scores5):
#     print(i + 892, p['class_ids'][0])
    res.append([i + 892, p['class_ids'][0]])   

#to df then to series and save to file
result = pd.DataFrame(res, columns=['PassengerId', 'Survived'])
result.to_csv('model5.csv', index=None)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/model5/model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
